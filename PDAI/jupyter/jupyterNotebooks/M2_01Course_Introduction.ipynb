# %% [markdown]
# <center><font size="+4">Programming & Data Analytics & AI 2 ML</font></center>
# <center><font size="+2">2025/2026</font></center>
# <center><img src="https://github.com/EMbeDS-education/ComputingDataAnalysisModeling20242025/raw/main/PDAI/jupyter/jupyterNotebooks/images/sssaLEMBEDSdtu.png" width="900" alt="L'EMbeDS"></center>
#
# <center><font size="+2">Course responsible</font></center>
# <center><font size="+2">Andrea Vandin a.vandin@santannapisa.it</font></center>
#
# ---

# %% [markdown]
# <center><font size="+4">Part 1</font></center>
# <center><font size="+4">Lecture 1: Course introduction</font></center>

# %% [markdown]
# ---

# %% [markdown]
# # Course website & material
# All material used in this course, including jupyter notebooks, datasets, schedule are available at the usual wiki
# - https://github.com/EMbeDS-education/ComputingDataAnalysisModeling20252026/wiki/PDAI
#
# __This is the second module of PDAI__
# - In __Module 1__ we learned about producing __software programs of good quality__, and how to use python and jupyter-lab
#   - **If you are not familiar with any of these topics: go through the material of Module 1**, available in the above link
# - In __Module 2__ we learn about producingm __data analysis projects of good quality__, and how to use some popular additional python libraries

# %% [markdown]
# # Course structure
#
# **Part 1: _We first build our toolset_**
# - Topics
#   - Advanced Libraries for data manipulation/visualization
#     - Matplotlib
#     - NumPy
#     - Pandas
#   - Exploratory Data Analysis (EDA) on the Titanic Dataset
#   - Work on assignments, preliminary project work if time permits
# - When
#   - Classes 1-2
#
#
# **Part 2, _We apply our toolset on a concrete Machine Learning case study_**
# - Topics
#   - [Breast Cancer Wisconsin (Diagnostic) Data Set](https://archive.ics.uci.edu/ml/datasets/Breast+Cancer+Wisconsin+(Diagnostic))
#     - Exploratory Data Analysis (data pre-processing, outliers detection, ...)
#     - Dimensionality Reduction (PCA)
#     - Clustering (K-means)
#     - Classification (of Benign and Malignant Breast Cancer)
# - When
#   - Classes 3-5
#
#
# **Part 3, _Research-driven/advanced topics_**
# - Topics
#   - __Neural networks, Graph neural networks__
#   - __Generative AI and LLM__
#   - Process-oriented Data Science: [Process mining](https://pm4py.fit.fraunhofer.de/getting-started-page#understanding)
# - When
#   - Classes 6-8

# %%
from IPython.display import Image, display
#img=Image(filename='images/tentativeLecturePlan.png',width=700)
url_github_repo="https://github.com/EMbeDS-education/ComputingDataAnalysisModeling20252026/raw/main/PDAI/jupyter/jupyterNotebooks/"
from IPython.display import display, Markdown, Latex


display(Markdown('<center><font size="+4">Part 1: We first build our toolset</font></center>'))
print()
print('\nPython is very popular')
print('https://www.tiobe.com/tiobe-index/')
img=Image(url_github_repo+'images/tiobeNov2023.png',width=500)
display(img)
print()
print('\nWhy is python so popular!?')
img=Image(url_github_repo+'images/pythoncpp.jpeg',width=500)
display(img)
print()
print('\nSlicing data...')
img=Image(url_github_repo+'images/slice.png',width=500)
display(img)
print()
print('\nAnalysing data: Finance data')
img=Image(url_github_repo+'images/finance.png',width=500)
display(img)
print('\nAnalysing data: COVID data')
img=Image(url_github_repo+'images/covid.png',width=520)
display(img)

print()
print()
display(Markdown('---'))
print()
print()
# Out:
# <center><font size="+4">Part 1: We first build our toolset</font></center>
# Python is very popular
# https://www.tiobe.com/tiobe-index/
# Why is python so popular!?
# Slicing data...
# Analysing data: Finance data
# Analysing data: COVID data
# ---

# %%
display(Markdown('<center><font size="+4">Part 2: We apply our toolset to a famous case study</font></center>'))
print('No students were harmed in previous editions...')
img=Image(url_github_repo+'images/memeTitanicBreastCancer.jpeg',width=500)
#img=Image(url_github_repo+'images/Breast-Biopsy-2.jpg',width=500)
display(img)
print()
print('Biopsy')
img=Image(url_github_repo+'images/Breast-Biopsy-2.jpg',width=500)
display(img)
print()
print('Can we classify benign and malignant breast cancers?')
img=Image(url_github_repo+'images/fna-benign1.png',width=500)
display(img)
img=Image(url_github_repo+'images/fna-malignant1.png',width=500)
display(img)

print()
print()
display(Markdown('---'))
print()
print()
# Out:
# <center><font size="+4">Part 2: We apply our toolset to a famous case study</font></center>
# No students were harmed in previous editions...
# Biopsy
# Can we classify benign and malignant breast cancers?
# ---

# %%
display(Markdown('<center><font size="+4">Part 3: Advanced topics</font></center>'))
print('##################################################')
print('CLASS 6: Neural networks and graph neural networks')
print('##################################################\n')
img=Image(url_github_repo+'images/artificialNN.png',width=600)
display(img)
img=Image('https://theaisummer.com/static/cb743cf6762bf14d48c1548bf0f0fe1f/9a128/gnn.jpg',width=800)
display(img)

print('################################################')
print('CLASS 7: Generative AI and Large Language Models')
print('################################################\n')
img=Image(url_github_repo+'images/GenAILLM.png',width=800)
display(img)
img=Image(url_github_repo+'images/GenAILLM2.png',width=800)
display(img)

print('######################################################')
print('CLASS 8: Process-oriented data science: Process Mining')
print('######################################################\n')
img=Image(url_github_repo+'images/PM.png',width=800)
display(img)


display(Markdown('---'))
# Out:
# <center><font size="+4">Part 3: Advanced topics</font></center>
# ##################################################
# CLASS 6: Neural networks and graph neural networks
# ##################################################
# ################################################
# CLASS 7: Generative AI and Large Language Models
# ################################################
# ######################################################
# CLASS 8: Process-oriented data science: Process Mining
# ######################################################
# ---

# %% [markdown]
# # Learning objectives
# A student who has met the objectives of the course will be able to:
# - **describe** the main steps and problematics involved in data anlysis and machine learning problems
# - **describe** and **use** advanced Python libraries for data analytics and machine learning
# - **apply** such libraries to medium-complexity problems
# - **describe** modern graphical programming languages for data analysis
# - **describe** the pipeline of steps/problems common in data analysis tasks
# - **communicate** analysis results in a clear and precise manner using popular web-based editors

# %% [markdown]
# # How are we going to evaluate you?
#
# ## Oral examination based on a report on assignments & project
# * _Assignments_
#     * Similarly to module 1, we provided 2 sets of simple coding assignments
#     * These are to test the topics somehow complementarily to the project work
#     * You shall hand in your assignments by the exam date.
# * _Project report_
#     * You will be given a simple _classic_ dataset
#       * Would have you survived the Titanic shipwreck?
#       * Or __you can propose one of interest if any__
#         - Please contact us
#         - You can do this only if we explicitly agree
#     * You will be asked to do a data-analysis project
#
# * Groups
#     * You can form __groups of 3 or 2 students__
#        * Both for the assignments and the project
#     * We will do a group oral examination based on your assignments and project

# %% [markdown]
# > _Needless to say, we will keep making __kahoot__ quizzes!_

# %% [markdown]
# ## The project
# - Consider the **Titanic** dataset available in the __datasets__ page of our wiki
#     - You will also find a **description** there
#   - Or contact us if you want to propose a dataset of interest.
# - It contains information on 1309 passengers
#   - 14 properties/attributes
#   - 1 target variable on the survival of the passenger
# - __Your task is to analyze this dataset in the lines of what shown in the course__
#   - The final goal is to **obtain a classifier able to predict the survival probability of a hypotethical passenger**
#     - Or other classification tasks to be agreed on if you use a dataset of interest
#   - BEWARE:
#     - Try first to understand the data. Read the provided description.
#     - Not all datasets are the same
#       - Do not just blindly apply all tasks seen in class, with the same parameters.
#       - Try to perform reasoned choices.
#       -  You are free to choose part of the techniques/tools seen during the course
#          - **Motivate your choices**
#     - You should prepare a [jupyterLab notebook](https://jupyterlab.readthedocs.io/en/stable/), or colab notebook (which is the same thing) containing your analysis
#       - **Properly commenting/motivating each step with suitable comments**
#       - Similarly to what we do in the jupyterLab notebooks we use in our classes

# %% [markdown]
# ## Form your group!

# %% [markdown]
# >Please __form a group and add it here__
# > - __DO IT BY NEXT CLASS__

# %%
googleDoc="https://docs.google.com/document/d/1yy6sZX77aoxbREDq0vIl1Nv0466OEf2qDzOCYzY6-wQ/edit?usp=sharing"
googleDoc
# Out:
# 'https://docs.google.com/document/d/1yy6sZX77aoxbREDq0vIl1Nv0466OEf2qDzOCYzY6-wQ/edit?usp=sharing'

# %%
from IPython.display import IFrame
IFrame(googleDoc, 1300, 700)
# Out:
#         <iframe
#             width="1300"
#             height="700"
#             src="https://docs.google.com/document/d/1yy6sZX77aoxbREDq0vIl1Nv0466OEf2qDzOCYzY6-wQ/edit?usp=sharing"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ---

# %% [markdown]
# # Kahoot

# %% [markdown]
# <!-- ![Last kahoot meme](images/lastKahootMeme.jpg) -->
#
# But now, the most entertaining part this course :D
# - Let's Kahoot!

# %% [markdown]
# How?
# * Using your phone or a different display go to [https://kahoot.it/](https://kahoot.it/)
# * Type the given PIN

# %%
from IPython.display import IFrame
IFrame("https://kahoot.it/", 500, 400)
# Out:
#         <iframe
#             width="500"
#             height="400"
#             src="https://kahoot.it/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
