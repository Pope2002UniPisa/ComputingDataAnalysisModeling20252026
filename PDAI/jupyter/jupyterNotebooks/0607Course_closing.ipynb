# %% [markdown]
# <center><font size="+4">Programming & Data Analytics & AI 1 2024/2025</font></center>
# <center><font size="+2">Sant'Anna School of Advanced Studies, Pisa, Italy</font></center>
# <center><img src="https://github.com/EMbeDS-education/ComputingDataAnalysisModeling20242025/raw/main/PDAI/jupyter/jupyterNotebooks/images/sssaLEMBEDSdtu.png" width="900" alt="L'EMbeDS"></center>
#
# <center><font size="+2">Course responsible</font></center>
# <center><font size="+2">Andrea Vandin a.vandin@santannapisa.it</font></center>
#
# <center><font size="+2">Teaching Assistant </font></center>
# <center><font size="+2">Sima Sarv Ahrabi Sima.SarvAhrabi@santannapisa.it</font></center>
#
# ---

# %% [markdown]
# <center><font size="+4">Programming & Data Analytics & AI 1 2025/2026</font></center>
# <center><font size="+2">Sant'Anna School of Advanced Studies, Pisa, Italy</font></center>
# <center><img src="https://github.com/EMbeDS-education/ComputingDataAnalysisModeling20242025/raw/main/PDAI/jupyter/jupyterNotebooks/images/sssaLEMBEDSdtu.png" width="900" alt="L'EMbeDS"></center>
#
# <center><font size="+2">Course responsible</font></center>
# <center><font size="+2">Andrea Vandin a.vandin@santannapisa.it</font></center>
#
# ---

# %% [markdown]
# <center><font size="+4">Lectures 6 and 7: Course closing</font></center>

# %% [markdown]
# ---

# %%
from IPython.display import Image, display
url_github_repo="https://github.com/EMbeDS-education/ComputingDataAnalysisModeling20252026/raw/main/PDAI/"

# %% [markdown]
# # What have we learned?

# %%
img=Image(url_github_repo+'jupyter/jupyterNotebooks/images/lastKahootMeme.JPG',width=700)
display(img)

# %% [markdown]
# We managed to
# * Cover all topics
# * Give applications
# * Let you improve and monitor your learning process using online platforms
#   * Assignments
#   * Kahoot quizzes

# %% [markdown]
# # The final exam

# %% [markdown]
# __The exam__
# * The exam is an oral examination with me
# * We will do it remotely using WebEx
# * The oral examination will start discussing some of the solutions you gave to the assignments,
#   * From there we might ask you additional questions about topics covered in the course
#   * __Therefore you should complete the assignments!__
#
# __Who is interested in the exam?__
# * Book a time slot for the exam in the Google sheet below
#   * Do it now if you have not done it yet
#   * No free slots? Please send us an email.
# * On the day and time of your exam
#   - Follow this link to Andrea Vandin's WebEx virtual room: https://santannapisa.webex.com/meet/a.vandin
#   - We have a tight schedule. __Be there on time!__

# %%
from IPython.display import IFrame
google_doc_exam="https://docs.google.com/spreadsheets/d/1zULREhC0WVGLCzJglcY-YsmRLpOzih0SBIapS402ljw/edit?usp=sharing"
print(google_doc_exam)
IFrame(google_doc_exam, 1000, 700)
# Out:
# https://docs.google.com/spreadsheets/d/1zULREhC0WVGLCzJglcY-YsmRLpOzih0SBIapS402ljw/edit?usp=sharing
#         <iframe
#             width="1000"
#             height="700"
#             src="https://docs.google.com/spreadsheets/d/1zULREhC0WVGLCzJglcY-YsmRLpOzih0SBIapS402ljw/edit?usp=sharing"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# # Closing remarks

# %% [markdown]
# Thank you for your participation to this first module
# - We managed to cover all planned topics
# - We hope to
#   - Have managed to instill in you a greater respect towards
#      - the _art of programming_, and
#      - a number of _general rules_ and _best practices_ to follow to get good-quality software
#   - Have made this course interesting and entertaining
#   - Get feedback from you on how to improve the course.
#
# > We hope to see you at M2 in next semester or in future editions of it.

# %% [markdown]
# > __The party is not over yet__
# >
# > __Let's move to the Numpy_Pandas notebook__
